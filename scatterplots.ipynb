# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# !pip install undetected-chromedriver
# Out:
# Collecting undetected-chromedriver
#   Downloading undetected-chromedriver-3.5.5.tar.gz (65 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting selenium>=4.9.0 (from undetected-chromedriver)
#   Downloading selenium-4.43.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: requests in c:\users\migue\anaconda3\lib\site-packages (from undetected-chromedriver) (2.32.3)
# Collecting websockets (from undetected-chromedriver)
#   Downloading websockets-16.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: certifi>=2026.1.4 in c:\users\migue\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (2026.1.4)
# Collecting trio<1.0,>=0.31.0 (from selenium>=4.9.0->undetected-chromedriver)
#   Downloading trio-0.33.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium>=4.9.0->undetected-chromedriver)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting typing_extensions<5.0,>=4.15.0 (from selenium>=4.9.0->undetected-chromedriver)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting urllib3<3.0,>=2.6.3 (from urllib3[socks]<3.0,>=2.6.3->selenium>=4.9.0->undetected-chromedriver)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\migue\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\migue\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (24.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\migue\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (2.4.0)
# Requirement already satisfied: idna in c:\users\migue\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (3.7)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\migue\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\migue\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium>=4.9.0->undetected-chromedriver)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\migue\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium>=4.9.0->undetected-chromedriver) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\migue\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium>=4.9.0->undetected-chromedriver) (2.21)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\migue\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium>=4.9.0->undetected-chromedriver) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\migue\anaconda3\lib\site-packages (from requests->undetected-chromedriver) (3.3.2)
# Downloading selenium-4.43.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.6 MB 11.8 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.6 MB 11.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.6 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 8.9 MB/s eta 0:00:00
# Downloading trio-0.33.0-py3-none-any.whl (510 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Downloading websockets-16.0-cp313-cp313-win_amd64.whl (178 kB)
# Building wheels for collected packages: undetected-chromedriver
#   Building wheel for undetected-chromedriver (setup.py): started
#   Building wheel for undetected-chromedriver (setup.py): finished with status 'done'
#   Created wheel for undetected-chromedriver: filename=undetected_chromedriver-3.5.5-py3-none-any.whl size=47131 sha256=3790d1f074ae3e7c663e47d0ac9d3cec25610f71ee9565ac4a7d022c41a53572
#   Stored in directory: c:\users\migue\appdata\local\pip\cache\wheels\7a\5f\c1\06f68421cc7172ef51504631252870bcb3a2fdf3b6a025f362
# Successfully built undetected-chromedriver
# Installing collected packages: wsproto, websockets, urllib3, typing_extensions, outcome, trio, trio-websocket, selenium, undetected-chromedriver
#
#    ---- ----------------------------------- 1/9 [websockets]
#   Attempting uninstall: urllib3
#    ---- ----------------------------------- 1/9 [websockets]
#     Found existing installation: urllib3 2.3.0
#    ---- ----------------------------------- 1/9 [websockets]
#     Uninstalling urllib3-2.3.0:
#    ---- ----------------------------------- 1/9 [websockets]
#       Successfully uninstalled urllib3-2.3.0
#    ---- ----------------------------------- 1/9 [websockets]
#    -------- ------------------------------- 2/9 [urllib3]
#    -------- ------------------------------- 2/9 [urllib3]
#   Attempting uninstall: typing_extensions
#    -------- ------------------------------- 2/9 [urllib3]
#     Found existing installation: typing_extensions 4.12.2
#    -------- ------------------------------- 2/9 [urllib3]
#     Uninstalling typing_extensions-4.12.2:
#    -------- ------------------------------- 2/9 [urllib3]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ------------- -------------------------- 3/9 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ------------- -------------------------- 3/9 [typing_extensions]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ---------------------- ----------------- 5/9 [trio]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ------------------------------- -------- 7/9 [selenium]
#    ---------------------------------------- 9/9 [undetected-chromedriver]
#
# Successfully installed outcome-1.3.0.post0 selenium-4.43.0 trio-0.33.0 trio-websocket-0.12.2 typing_extensions-4.15.0 undetected-chromedriver-3.5.5 urllib3-2.6.3 websockets-16.0 wsproto-1.3.2
#   DEPRECATION: Building 'undetected-chromedriver' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'undetected-chromedriver'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
import pandas as pd
import undetected_chromedriver as uc

from bs4 import BeautifulSoup

# %%
driver = uc.Chrome()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 driver = uc.Chrome()
#
# File c:\Users\migue\anaconda3\Lib\site-packages\undetected_chromedriver\__init__.py:466, in Chrome.__init__(self, options, user_data_dir, driver_executable_path, browser_executable_path, port, enable_cdp_events, desired_capabilities, advanced_elements, keep_alive, log_level, headless, version_main, patcher_force_close, suppress_welcome, use_subprocess, debug, no_sandbox, user_multi_procs, **kw)
#     459     self.browser_pid = browser.pid
#     462 service = selenium.webdriver.chromium.service.ChromiumService(
#     463     self.patcher.executable_path
#     464 )
# --> 466 super(Chrome, self).__init__(
#     467     service=service,
#     468     options=options,
#     469     keep_alive=keep_alive,
#     470 )
#     472 self.reactor = None
#     474 if enable_cdp_events:
#
# File c:\Users\migue\anaconda3\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File c:\Users\migue\anaconda3\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:66, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      57 executor = ChromiumRemoteConnection(
#      58     remote_server_addr=self.service.service_url,
#      59     browser_name=browser_name,
#    (...)
#      62     ignore_proxy=self.options._ignore_local_proxy,
#      63 )
#      65 try:
# ---> 66     super().__init__(command_executor=executor, options=self.options)
#      67 except Exception:
#      68     self.quit()
#
# File c:\Users\migue\anaconda3\Lib\site-packages\selenium\webdriver\common\webdriver.py:25, in LocalWebDriver.__init__(self, *args, **kwargs)
#      24 def __init__(self, *args, **kwargs):
# ---> 25     super().__init__(*args, **kwargs)
#      26     self._is_remote = False
#
# File c:\Users\migue\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:274, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     272 self._authenticator_id = None
#     273 self.start_client()
# --> 274 self.start_session(capabilities)
#     275 self._fedcm = FedCM(self)
#     277 self._websocket_connection: WebSocketConnection | None = None
#
# File c:\Users\migue\anaconda3\Lib\site-packages\undetected_chromedriver\__init__.py:724, in Chrome.start_session(self, capabilities, browser_profile)
#     722 if not capabilities:
#     723     capabilities = self.options.to_capabilities()
# --> 724 super(selenium.webdriver.chrome.webdriver.WebDriver, self).start_session(
#     725     capabilities
#     726 )
#
# File c:\Users\migue\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:370, in WebDriver.start_session(self, capabilities)
#     368 caps = _create_caps(capabilities)
#     369 try:
# --> 370     response = self.execute(Command.NEW_SESSION, caps)["value"]
#     371     self.session_id = response.get("sessionId")
#     372     self.caps = response.get("capabilities")
#
# File c:\Users\migue\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:450, in WebDriver.execute(self, driver_command, params)
#     447 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     449 if response:
# --> 450     self.error_handler.check_response(response)
#     451     response["value"] = self._unwrap_value(response.get("value", None))
#     452     return response
#
# File c:\Users\migue\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: cannot connect to chrome at 127.0.0.1:56628
# from session not created: This version of ChromeDriver only supports Chrome version 148
# Current browser version is 147.0.7727.102; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#sessionnotcreatedexception
# Stacktrace:
# 	undetected_chromedriver!GetHandleVerifier [0xc7f533+10813]
# 	undetected_chromedriver!GetHandleVerifier [0xc7f664+10944]
# 	undetected_chromedriver!(No symbol) [0xa81ec0]
# 	undetected_chromedriver!(No symbol) [0xabdd22]
# 	undetected_chromedriver!(No symbol) [0xabcd5c]
# 	undetected_chromedriver!(No symbol) [0xab2e55]
# 	undetected_chromedriver!(No symbol) [0xab2c76]
# 	undetected_chromedriver!(No symbol) [0xaf94af]
# 	undetected_chromedriver!(No symbol) [0xaf8cc7]
# 	undetected_chromedriver!(No symbol) [0xaed546]
# 	undetected_chromedriver!(No symbol) [0xac0919]
# 	undetected_chromedriver!(No symbol) [0xac16d4]
# 	undetected_chromedriver!GetHandleVerifier [0xf04574+295854]
# 	undetected_chromedriver!GetHandleVerifier [0xeffb61+290e41]
# 	undetected_chromedriver!GetHandleVerifier [0xf21055+2b2335]
# 	undetected_chromedriver!GetHandleVerifier [0xc98b38+29e18]
# 	undetected_chromedriver!GetHandleVerifier [0xca03bd+3169d]
# 	undetected_chromedriver!GetHandleVerifier [0xc87df8+190d8]
# 	undetected_chromedriver!GetHandleVerifier [0xc87fa5+19285]
# 	undetected_chromedriver!GetHandleVerifier [0xc7164f+292f]
# 	KERNEL32!BaseThreadInitThunk [0x76735d49+19]
# 	ntdll!RtlInitializeExceptionChain [0x7771d83b+6b]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x7771d7c1+231]
